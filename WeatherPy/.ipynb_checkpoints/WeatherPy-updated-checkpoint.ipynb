# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Add url
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
response = requests.get(f"{url}appid={weather_api_key}&units={units}&q=London")
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 8
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.5085,
#         "lon": -0.1257
#     },
#     "dt": 1617061554,
#     "id": 2643743,
#     "main": {
#         "feels_like": 4.29,
#         "humidity": 66,
#         "pressure": 1030,
#         "temp": 6.85,
#         "temp_max": 9,
#         "temp_min": 5.56
#     },
#     "name": "London",
#     "sys": {
#         "country": "GB",
#         "id": 1414,
#         "sunrise": 1617082801,
#         "sunset": 1617128974,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 1.03
#     }
# }

# %%
city_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

record_count = 1
set_count = 1

# %%
for i,city in enumerate(cities):
    if (i%50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    except:
        print(f"City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | bubaque
# Processing Record 3 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 1 | sao filipe
# Processing Record 5 of Set 1 | salalah
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | kosaya gora
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | porbandar
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | taoudenni
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | caravelas
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | ust-kuyga
# Processing Record 25 of Set 1 | kenai
# Processing Record 26 of Set 1 | husavik
# Processing Record 27 of Set 1 | sakakah
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | lata
# Processing Record 30 of Set 1 | aksu
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | barcelos
# Processing Record 35 of Set 1 | virginia beach
# Processing Record 36 of Set 1 | gizo
# Processing Record 37 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 1 | bogo
# Processing Record 39 of Set 1 | belmonte
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | kavaratti
# Processing Record 43 of Set 1 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | maragogi
# Processing Record 46 of Set 1 | christchurch
# Processing Record 47 of Set 1 | anloga
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | mastic
# Processing Record 0 of Set 2 | ribeira grande
# Processing Record 1 of Set 2 | west wendover
# Processing Record 2 of Set 2 | portland
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | ejea de los caballeros
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | port pirie
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | sipe sipe
# Processing Record 10 of Set 2 | camopi
# Processing Record 11 of Set 2 | beloha
# Processing Record 12 of Set 2 | kropachevo
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | abu samrah
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 2 | thaton
# Processing Record 21 of Set 2 | la ronge
# Processing Record 22 of Set 2 | cacota
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | malacky
# Processing Record 27 of Set 2 | daliao
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | mayumba
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | vao
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | ouesso
# Processing Record 35 of Set 2 | workington
# Processing Record 36 of Set 2 | abha
# Processing Record 37 of Set 2 | poya
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | arman
# Processing Record 41 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | skibbereen
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | kyren
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | severo-yeniseyskiy
# Processing Record 48 of Set 2 | geraldton
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 0 of Set 3 | vanimo
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | praia da vitoria
# Processing Record 3 of Set 3 | korzhevskiy
# Processing Record 4 of Set 3 | beringovskiy
# Processing Record 5 of Set 3 | bakchar
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | birakan
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | ambon
# Processing Record 11 of Set 3 | hanstholm
# Processing Record 12 of Set 3 | konispol
# Processing Record 13 of Set 3 | yermish
# Processing Record 14 of Set 3 | lulea
# Processing Record 15 of Set 3 | araceli
# Processing Record 16 of Set 3 | college
# Processing Record 17 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 3 | bull savanna
# Processing Record 19 of Set 3 | vardo
# Processing Record 20 of Set 3 | kawambwa
# Processing Record 21 of Set 3 | zonguldak
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | malatya
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | san nicolas
# Processing Record 28 of Set 3 | puerto carreno
# Processing Record 29 of Set 3 | patacamaya
# Processing Record 30 of Set 3 | moree
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | flinders
# Processing Record 33 of Set 3 | general pico
# Processing Record 34 of Set 3 | harper
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | nhulunbuy
# Processing Record 38 of Set 3 | lavrentiya
# Processing Record 39 of Set 3 | miraflores
# Processing Record 40 of Set 3 | seinajoki
# Processing Record 41 of Set 3 | port augusta
# Processing Record 42 of Set 3 | visby
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | mount gambier
# Processing Record 45 of Set 3 | san quintin
# Processing Record 46 of Set 3 | emerald
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | sept-iles
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 0 of Set 4 | olinda
# Processing Record 1 of Set 4 | san andres
# Processing Record 2 of Set 4 | bafoulabe
# Processing Record 3 of Set 4 | san agustin acasaguastlan
# Processing Record 4 of Set 4 | walvis bay
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | sosua
# Processing Record 7 of Set 4 | usuki
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | masvingo
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | bengkulu
# Processing Record 12 of Set 4 | callaguip
# Processing Record 13 of Set 4 | hambantota
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | nangomba
# Processing Record 16 of Set 4 | geilo
# Processing Record 17 of Set 4 | tuktoyaktuk
# Processing Record 18 of Set 4 | hami
# Processing Record 19 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | wysokie mazowieckie
# Processing Record 21 of Set 4 | praya
# Processing Record 22 of Set 4 | quelimane
# Processing Record 23 of Set 4 | normandin
# Processing Record 24 of Set 4 | kapitanivka
# Processing Record 25 of Set 4 | hovd
# Processing Record 26 of Set 4 | mandera
# Processing Record 27 of Set 4 | shchuchye
# City not found. Skipping...
# Processing Record 28 of Set 4 | hondo
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | kununurra
# Processing Record 32 of Set 4 | mount isa
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | zhezkazgan
# Processing Record 35 of Set 4 | vila franca do campo
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | curup
# Processing Record 39 of Set 4 | padang
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | zyryanka
# Processing Record 42 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | anadyr
# Processing Record 45 of Set 4 | aracati
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | massape
# Processing Record 48 of Set 4 | ponta pora
# Processing Record 49 of Set 4 | pishin
# Processing Record 0 of Set 5 | okhotsk
# Processing Record 1 of Set 5 | coos bay
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | cape town
# Processing Record 4 of Set 5 | tura
# Processing Record 5 of Set 5 | bontang
# Processing Record 6 of Set 5 | ligayan
# Processing Record 7 of Set 5 | bardiyah
# Processing Record 8 of Set 5 | kutum
# Processing Record 9 of Set 5 | tynda
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | pafos
# Processing Record 12 of Set 5 | buribay
# Processing Record 13 of Set 5 | tabuk
# Processing Record 14 of Set 5 | quballat
# Processing Record 15 of Set 5 | xining
# Processing Record 16 of Set 5 | burica
# City not found. Skipping...
# Processing Record 17 of Set 5 | were ilu
# Processing Record 18 of Set 5 | deputatskiy
# Processing Record 19 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 5 | pauini
# Processing Record 21 of Set 5 | ossora
# Processing Record 22 of Set 5 | sur
# Processing Record 23 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 5 | prince rupert
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | chake chake
# Processing Record 27 of Set 5 | pringsewu
# Processing Record 28 of Set 5 | mindelo
# Processing Record 29 of Set 5 | atocha
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | olafsvik
# Processing Record 33 of Set 5 | mujiayingzi
# Processing Record 34 of Set 5 | tema
# Processing Record 35 of Set 5 | lundazi
# Processing Record 36 of Set 5 | nishihara
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | nanortalik
# Processing Record 39 of Set 5 | lorengau
# Processing Record 40 of Set 5 | port blair
# Processing Record 41 of Set 5 | lerwick
# Processing Record 42 of Set 5 | new norfolk
# Processing Record 43 of Set 5 | wardha
# Processing Record 44 of Set 5 | pasni
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | hualmay
# Processing Record 48 of Set 5 | vallenar
# Processing Record 49 of Set 5 | kaeo
# Processing Record 0 of Set 6 | bowling green
# Processing Record 1 of Set 6 | shelburne
# Processing Record 2 of Set 6 | koosa
# Processing Record 3 of Set 6 | ayan
# Processing Record 4 of Set 6 | coahuayana
# Processing Record 5 of Set 6 | kozhva
# Processing Record 6 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 6 | tazovskiy
# Processing Record 8 of Set 6 | bonthe
# Processing Record 9 of Set 6 | san cristobal
# Processing Record 10 of Set 6 | san jose
# Processing Record 11 of Set 6 | codajas
# Processing Record 12 of Set 6 | dikson
# Processing Record 13 of Set 6 | makakilo city
# Processing Record 14 of Set 6 | yola
# Processing Record 15 of Set 6 | swan river
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | merano
# Processing Record 18 of Set 6 | durusu
# Processing Record 19 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 20 of Set 6 | chalinze
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | davidson
# Processing Record 23 of Set 6 | zverinogolovskoye
# Processing Record 24 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 6 | rio grande
# Processing Record 26 of Set 6 | kendari
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | westport
# Processing Record 29 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 6 | lima
# Processing Record 31 of Set 6 | nyurba
# Processing Record 32 of Set 6 | kloulklubed
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | yerbogachen
# Processing Record 35 of Set 6 | muisne
# Processing Record 36 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 6 | chekhov
# Processing Record 38 of Set 6 | deqing
# Processing Record 39 of Set 6 | san ignacio
# Processing Record 40 of Set 6 | dossor
# Processing Record 41 of Set 6 | kefamenanu
# Processing Record 42 of Set 6 | moron
# Processing Record 43 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 6 | zaranj
# Processing Record 45 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 6 | piacabucu
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | laerdalsoyri
# Processing Record 49 of Set 6 | kyabram
# Processing Record 0 of Set 7 | quatre cocos
# Processing Record 1 of Set 7 | damara
# Processing Record 2 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 7 | sorland
# Processing Record 4 of Set 7 | valdosta
# Processing Record 5 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 7 | pangkalanbuun
# Processing Record 7 of Set 7 | vertou
# Processing Record 8 of Set 7 | oksfjord
# Processing Record 9 of Set 7 | codrington
# Processing Record 10 of Set 7 | orange cove
# Processing Record 11 of Set 7 | batesville
# Processing Record 12 of Set 7 | pechora
# Processing Record 13 of Set 7 | san miguel
# Processing Record 14 of Set 7 | sisimiut
# Processing Record 15 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 7 | ewa beach
# Processing Record 17 of Set 7 | ketchikan
# Processing Record 18 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 7 | amga
# Processing Record 20 of Set 7 | nador
# Processing Record 21 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 7 | georgetown
# Processing Record 23 of Set 7 | wawa
# Processing Record 24 of Set 7 | eureka
# Processing Record 25 of Set 7 | tuatapere
# Processing Record 26 of Set 7 | constitucion
# Processing Record 27 of Set 7 | svetlogorsk
# Processing Record 28 of Set 7 | lubao
# Processing Record 29 of Set 7 | viesite
# Processing Record 30 of Set 7 | nantucket
# Processing Record 31 of Set 7 | fortuna
# Processing Record 32 of Set 7 | sao joao da barra
# Processing Record 33 of Set 7 | sitka
# Processing Record 34 of Set 7 | aljezur
# Processing Record 35 of Set 7 | souillac
# Processing Record 36 of Set 7 | uray
# Processing Record 37 of Set 7 | perama
# Processing Record 38 of Set 7 | isangel
# Processing Record 39 of Set 7 | san pedro
# Processing Record 40 of Set 7 | promyshlennaya
# Processing Record 41 of Set 7 | port hedland
# Processing Record 42 of Set 7 | tabou
# Processing Record 43 of Set 7 | grand gaube
# Processing Record 44 of Set 7 | rio gallegos
# Processing Record 45 of Set 7 | lagoa
# Processing Record 46 of Set 7 | algiers
# Processing Record 47 of Set 7 | timra
# Processing Record 48 of Set 7 | gaziantep
# Processing Record 49 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 0 of Set 8 | nova odesa
# Processing Record 1 of Set 8 | atasu
# Processing Record 2 of Set 8 | taraclia
# Processing Record 3 of Set 8 | the valley
# Processing Record 4 of Set 8 | acarau
# Processing Record 5 of Set 8 | tavda
# Processing Record 6 of Set 8 | mayaky
# Processing Record 7 of Set 8 | juneau
# Processing Record 8 of Set 8 | phangnga
# Processing Record 9 of Set 8 | la florida
# Processing Record 10 of Set 8 | kavant
# City not found. Skipping...
# Processing Record 11 of Set 8 | beyneu
# Processing Record 12 of Set 8 | naze
# Processing Record 13 of Set 8 | vila velha
# Processing Record 14 of Set 8 | mackenzie
# Processing Record 15 of Set 8 | havre
# Processing Record 16 of Set 8 | pemangkat
# Processing Record 17 of Set 8 | harstad
# Processing Record 18 of Set 8 | ca mau
# Processing Record 19 of Set 8 | mandalgovi
# Processing Record 20 of Set 8 | cidreira
# Processing Record 21 of Set 8 | saint-marc
# Processing Record 22 of Set 8 | varkaus
# Processing Record 23 of Set 8 | the pas
# Processing Record 24 of Set 8 | asau
# Processing Record 25 of Set 8 | tsalka
# Processing Record 26 of Set 8 | mehamn
# Processing Record 27 of Set 8 | vostok
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | jadu
# Processing Record 30 of Set 8 | pacific grove
# Processing Record 31 of Set 8 | haverfordwest
# Processing Record 32 of Set 8 | ponta do sol
# Processing Record 33 of Set 8 | namibe
# Processing Record 34 of Set 8 | grindavik
# Processing Record 35 of Set 8 | esna
# Processing Record 36 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 37 of Set 8 | akyab
# Processing Record 38 of Set 8 | palmer
# Processing Record 39 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 40 of Set 8 | teguise
# Processing Record 41 of Set 8 | pombia
# Processing Record 42 of Set 8 | ulladulla
# Processing Record 43 of Set 8 | nouakchott
# Processing Record 44 of Set 8 | xuddur
# Processing Record 45 of Set 8 | cockburn town
# Processing Record 46 of Set 8 | gimli
# Processing Record 47 of Set 8 | vaasa
# Processing Record 48 of Set 8 | vilyuysk
# Processing Record 49 of Set 8 | tessalit
# Processing Record 0 of Set 9 | ikeda
# Processing Record 1 of Set 9 | muros
# Processing Record 2 of Set 9 | nizhnevartovsk
# Processing Record 3 of Set 9 | disna
# Processing Record 4 of Set 9 | ontario
# Processing Record 5 of Set 9 | fayaoue
# Processing Record 6 of Set 9 | lebyazhye
# Processing Record 7 of Set 9 | san policarpo
# Processing Record 8 of Set 9 | ohangaron
# Processing Record 9 of Set 9 | yulara
# Processing Record 10 of Set 9 | saint-joseph
# Processing Record 11 of Set 9 | puerto colombia
# Processing Record 12 of Set 9 | kayerkan
# Processing Record 13 of Set 9 | pitimbu
# Processing Record 14 of Set 9 | dapaong
# Processing Record 15 of Set 9 | brae
# Processing Record 16 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 9 | necochea
# Processing Record 18 of Set 9 | mondlo
# Processing Record 19 of Set 9 | jibuti
# Processing Record 20 of Set 9 | buala
# Processing Record 21 of Set 9 | namatanai
# Processing Record 22 of Set 9 | havre-saint-pierre
# Processing Record 23 of Set 9 | upington
# Processing Record 24 of Set 9 | kroya
# Processing Record 25 of Set 9 | laguna
# Processing Record 26 of Set 9 | batemans bay
# Processing Record 27 of Set 9 | rochegda
# Processing Record 28 of Set 9 | gavle
# Processing Record 29 of Set 9 | sao jose da coroa grande
# Processing Record 30 of Set 9 | taltal
# Processing Record 31 of Set 9 | karratha
# Processing Record 32 of Set 9 | margate
# Processing Record 33 of Set 9 | nakanojo
# Processing Record 34 of Set 9 | talnakh
# Processing Record 35 of Set 9 | marsaxlokk
# Processing Record 36 of Set 9 | warangal
# Processing Record 37 of Set 9 | dudinka
# Processing Record 38 of Set 9 | santa catalina
# Processing Record 39 of Set 9 | chaoyang
# Processing Record 40 of Set 9 | sao joao do piaui
# Processing Record 41 of Set 9 | esmeraldas
# Processing Record 42 of Set 9 | novikovo
# Processing Record 43 of Set 9 | ancud
# Processing Record 44 of Set 9 | tual
# Processing Record 45 of Set 9 | hofn
# Processing Record 46 of Set 9 | nemuro
# Processing Record 47 of Set 9 | tombouctou
# Processing Record 48 of Set 9 | tacuarembo
# Processing Record 49 of Set 9 | lethem
# Processing Record 0 of Set 10 | flin flon
# Processing Record 1 of Set 10 | huntingdon
# Processing Record 2 of Set 10 | kearney
# Processing Record 3 of Set 10 | katwa
# Processing Record 4 of Set 10 | henties bay
# Processing Record 5 of Set 10 | port keats
# Processing Record 6 of Set 10 | saldanha
# Processing Record 7 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 10 | north platte
# Processing Record 9 of Set 10 | yuzhno-kurilsk
# Processing Record 10 of Set 10 | unity
# Processing Record 11 of Set 10 | ruwi
# Processing Record 12 of Set 10 | kapoeta
# Processing Record 13 of Set 10 | pekan
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | farafangana
# Processing Record 16 of Set 10 | porto santo
# Processing Record 17 of Set 10 | chimore
# Processing Record 18 of Set 10 | komsomolskiy
# Processing Record 19 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 10 | cherskiy
# Processing Record 21 of Set 10 | bealanana
# Processing Record 22 of Set 10 | nehe
# Processing Record 23 of Set 10 | alofi
# Processing Record 24 of Set 10 | cervo
# Processing Record 25 of Set 10 | kashi
# Processing Record 26 of Set 10 | george town
# Processing Record 27 of Set 10 | port moresby
# Processing Record 28 of Set 10 | vermilion
# Processing Record 29 of Set 10 | novaya igirma
# Processing Record 30 of Set 10 | acajutla
# Processing Record 31 of Set 10 | kastamonu
# Processing Record 32 of Set 10 | kungurtug
# Processing Record 33 of Set 10 | awbari
# Processing Record 34 of Set 10 | porto torres
# Processing Record 35 of Set 10 | ariogala
# Processing Record 36 of Set 10 | languyan
# Processing Record 37 of Set 10 | meulaboh
# Processing Record 38 of Set 10 | knysna
# Processing Record 39 of Set 10 | baghmara
# Processing Record 40 of Set 10 | appleton
# Processing Record 41 of Set 10 | wewak
# Processing Record 42 of Set 10 | narasingapuram
# Processing Record 43 of Set 10 | sokolo
# Processing Record 44 of Set 10 | finkenstein
# Processing Record 45 of Set 10 | dzhebariki-khaya
# Processing Record 46 of Set 10 | teya
# Processing Record 47 of Set 10 | adana
# Processing Record 48 of Set 10 | tasiilaq
# Processing Record 49 of Set 10 | mafinga
# Processing Record 0 of Set 11 | klaksvik
# Processing Record 1 of Set 11 | santa cruz do sul
# Processing Record 2 of Set 11 | mogadishu
# Processing Record 3 of Set 11 | manakara
# Processing Record 4 of Set 11 | adrar
# Processing Record 5 of Set 11 | camacha
# Processing Record 6 of Set 11 | contai
# Processing Record 7 of Set 11 | eydhafushi
# Processing Record 8 of Set 11 | batagay-alyta
# Processing Record 9 of Set 11 | lumeje
# Processing Record 10 of Set 11 | orikhove
# Processing Record 11 of Set 11 | kruisfontein
# Processing Record 12 of Set 11 | igurusi
# Processing Record 13 of Set 11 | kappeln
# Processing Record 14 of Set 11 | sulphur
# Processing Record 15 of Set 11 | bay roberts
# Processing Record 16 of Set 11 | auki
# Processing Record 17 of Set 11 | mizan teferi
# Processing Record 18 of Set 11 | marsh harbour
# Processing Record 19 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 11 | vrede
# Processing Record 21 of Set 11 | tonantins
# Processing Record 22 of Set 11 | richards bay
# Processing Record 23 of Set 11 | hamilton
# Processing Record 24 of Set 11 | dunayivtsi
# City not found. Skipping...
# Processing Record 25 of Set 11 | nome
# Processing Record 26 of Set 11 | korla
# Processing Record 27 of Set 11 | manama
# Processing Record 28 of Set 11 | mocajuba
# Processing Record 29 of Set 11 | turkistan
# Processing Record 30 of Set 11 | morondava
# Processing Record 31 of Set 11 | huarmey
# Processing Record 32 of Set 11 | catuday
# Processing Record 33 of Set 11 | yichun
# Processing Record 34 of Set 11 | midyat
# Processing Record 35 of Set 11 | kibala
# Processing Record 36 of Set 11 | koygorodok
# Processing Record 37 of Set 11 | port-cartier
# Processing Record 38 of Set 11 | warrnambool
# Processing Record 39 of Set 11 | narovchat
# Processing Record 40 of Set 11 | koryukivka
# Processing Record 41 of Set 11 | wanlaweyn
# Processing Record 42 of Set 11 | macae
# Processing Record 43 of Set 11 | uarini
# Processing Record 44 of Set 11 | liwale
# Processing Record 45 of Set 11 | nalhati
# Processing Record 46 of Set 11 | clyde river
# Processing Record 47 of Set 11 | ellisras
# Processing Record 48 of Set 11 | shimoda
# Processing Record 49 of Set 11 | leningradskiy
# Processing Record 0 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 12 | zaysan
# Processing Record 2 of Set 12 | bowen
# Processing Record 3 of Set 12 | brora
# Processing Record 4 of Set 12 | champerico
# Processing Record 5 of Set 12 | kamenka
# Processing Record 6 of Set 12 | wenshang
# Processing Record 7 of Set 12 | mumford
# Processing Record 8 of Set 12 | tadine
# Processing Record 9 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 10 of Set 12 | jalu
# Processing Record 11 of Set 12 | maniitsoq
# Processing Record 12 of Set 12 | ust-tsilma
# Processing Record 13 of Set 12 | sechura
# Processing Record 14 of Set 12 | neuquen
# Processing Record 15 of Set 12 | sambava
# Processing Record 16 of Set 12 | corinto
# Processing Record 17 of Set 12 | churu
# Processing Record 18 of Set 12 | sfantu gheorghe
# Processing Record 19 of Set 12 | gravelbourg
# Processing Record 20 of Set 12 | clovis
# Processing Record 21 of Set 12 | kanina
# Processing Record 22 of Set 12 | linxia
# Processing Record 23 of Set 12 | pundri
# Processing Record 24 of Set 12 | lithgow
# Processing Record 25 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 12 | skelleftea
# Processing Record 27 of Set 12 | sarankhola
# Processing Record 28 of Set 12 | coquimbo
# Processing Record 29 of Set 12 | lanzhou
# Processing Record 30 of Set 12 | kauhajoki
# Processing Record 31 of Set 12 | grinnell
# Processing Record 32 of Set 12 | peremyshlyany
# Processing Record 33 of Set 12 | presidente franco
# Processing Record 34 of Set 12 | vuktyl
# Processing Record 35 of Set 12 | tayturka
# Processing Record 36 of Set 12 | sisophon
# Processing Record 37 of Set 12 | fairbanks
# Processing Record 38 of Set 12 | guilin
# Processing Record 39 of Set 12 | verkhnyaya inta
# Processing Record 40 of Set 12 | deniliquin
# Processing Record 41 of Set 12 | jiazi
# Processing Record 42 of Set 12 | grand island
# Processing Record 43 of Set 12 | ganzhou
# Processing Record 44 of Set 12 | dongsheng
# Processing Record 45 of Set 12 | sabha
# Processing Record 46 of Set 12 | kurilsk
# Processing Record 47 of Set 12 | yumen
# Processing Record 48 of Set 12 | kolokani
# Processing Record 49 of Set 12 | shatrovo
# Processing Record 0 of Set 13 | vagur
# Processing Record 1 of Set 13 | nabire
# Processing Record 2 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 13 | roma
# Processing Record 4 of Set 13 | lazaro cardenas
# Processing Record 5 of Set 13 | severiano melo
# Processing Record 6 of Set 13 | lakes entrance

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Make a dataframe from a dictonary
weather_dict = {
    "City": city_name,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date}

# %%
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Busselton -33.6500  115.3333     19.44        96          12        2.75
# 1     Bubaque  11.2833  -15.8333     24.37        71          12        6.20
# 2  São Filipe  14.8961  -24.4956     20.76        73          73        5.54
# 3     Salalah  17.0151   54.0924     27.00        54           0        2.06
# 4     Rikitea -23.1203 -134.9692     26.01        70           8        6.85
#
#   Country        Date
# 0      AU  1617062425
# 1      GW  1617062425
# 2      CV  1617062136
# 3      OM  1617062106
# 4      PF  1617062312

# %%
# Export to CSV
weather_data.to_csv(r'\Desktopweather_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data["Humidity"].max()
# Out:
# 100

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2021/03/29)")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2021/03/29)")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumitityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2021/03/29)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2021/03/29)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_weather_df = weather_data.loc[(weather_data["Lat"] >= 0)]
northern_weather_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1            Bubaque  11.2833  -15.8333     24.37        71          12
# 2         São Filipe  14.8961  -24.4956     20.76        73          73
# 3            Salalah  17.0151   54.0924     27.00        54           0
# 5        Kosaya Gora  54.1190   37.5446     -4.21        98          95
# 9          Porbandar  21.6422   69.6093     25.04        81           2
# ..               ...      ...       ...       ...       ...         ...
# 553         Kolokani  13.5728   -8.0339     26.43         9           4
# 554         Shatrovo  56.5167   64.6333    -12.26        99          82
# 555            Vágur  61.4732   -6.8119      6.20        70         100
# 557             Rome  43.2128  -75.4557      1.67        51           1
# 558  Lázaro Cárdenas  17.9583 -102.2000     27.47        51          90
#
#      Wind Speed Country        Date
# 1          6.20      GW  1617062425
# 2          5.54      CV  1617062136
# 3          2.06      OM  1617062106
# 5          2.53      RU  1617062426
# 9          4.20      IN  1617062427
# ..          ...     ...         ...
# 553        4.55      ML  1617062556
# 554        0.90      RU  1617062556
# 555        1.77      FO  1617062556
# 557        2.06      US  1617062545
# 558        3.65      MX  1617062558
#
# [393 rows x 9 columns]

# %%
southern_weather_df = weather_data.loc[(weather_data["Lat"] < 0)]
southern_weather_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Busselton -33.6500  115.3333     19.44        96          12
# 4              Rikitea -23.1203 -134.9692     26.01        70           8
# 6        Mar del Plata -38.0023  -57.5575     17.22        82          40
# 7              Ushuaia -54.8000  -68.3000     10.00        76          20
# 8                Vaini -21.2000 -175.2000     27.00        89          75
# ..                 ...      ...       ...       ...       ...         ...
# 538  Presidente Franco -25.5333  -54.6167     22.00        88          75
# 545         Deniliquin -35.5333  144.9667     15.56        66          25
# 556             Nabire  -3.3667  135.4833     29.04        66         100
# 559     Severiano Melo  -5.7772  -37.9578     23.50        92         100
# 560     Lakes Entrance -37.8811  147.9810     17.78        59          85
#
#      Wind Speed Country        Date
# 0          2.75      AU  1617062425
# 4          6.85      PF  1617062312
# 6          3.09      AR  1617062131
# 7          2.06      AR  1617062310
# 8          3.60      TO  1617061998
# ..          ...     ...         ...
# 538        1.54      PY  1617062552
# 545        0.89      AU  1617062554
# 556        0.53      ID  1617062557
# 559        2.47      BR  1617062558
# 560        0.45      AU  1617062289
#
# [168 rows x 9 columns]

# %%
x_values = northern_weather_df['Lat']
y_values = northern_weather_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.8734119802386379

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_weather_df['Lat']
y_values = southern_weather_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.6101623515049371

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_weather_df['Lat']
y_values = northern_weather_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.25861314139197106

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_weather_df['Lat']
y_values = southern_weather_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.1908740366525765

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_weather_df['Lat']
y_values = northern_weather_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.2370115125232574

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_weather_df['Lat']
y_values = southern_weather_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.3078533832987496

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_weather_df['Lat']
y_values = northern_weather_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.09932548596425053

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_weather_df['Lat']
y_values = southern_weather_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.013182611182728784
